# %%
df.hist()
plt.show()

# %%
df.describe()
# Out:
#        read_length
# count          8.0
# mean         151.0
# std            0.0
# min          151.0
# 25%          151.0
# 50%          151.0
# 75%          151.0
# max          151.0

# %%
df = pd.DataFrame({"read_length": lengths})
df
# Out:
#    read_length
# 0          151
# 1          151
# 2          151
# 3          151
# 4          151
# 5          151
# 6          151
# 7          151

# %%
file_path = Path("../data/raw/sample.fastq")

lengths = []

with open(file_path, "r") as f:
    lines = f.readlines()

for i in range(1, len(lines), 4):
    seq = lines[i].strip()
    if len(seq) > 0:
        lengths.append(len(seq))

lengths
# Out:
# [151, 151, 151, 151, 151, 151, 151, 151]

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # FASTQ exploratory QC
#
# Basic exploratory analysis of public NGS dataset.
#
# Goal:
# - read parsing
# - length analysis
# - summary statistics
